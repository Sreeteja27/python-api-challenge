# %%
# Dependencies and Setup
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as ow
from pprint import pprint
import datetime
# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
record_counter = 0
set_counter = 0
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0

    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
    print(query_url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("City not found!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ushuaia
# Processing record 2 of set 0 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=hilo
# Processing record 3 of set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=busselton
# Processing record 4 of set 0 | sanghar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=sanghar
# Processing record 5 of set 0 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=port alfred
# Processing record 6 of set 0 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=new norfolk
# Processing record 7 of set 0 | karakendzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=karakendzha
# City not found!
# Processing record 8 of set 0 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=dikson
# Processing record 9 of set 0 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=torbay
# Processing record 10 of set 0 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=taolanaro
# City not found!
# Processing record 11 of set 0 | kerki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kerki
# City not found!
# Processing record 12 of set 0 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=bredasdorp
# Processing record 13 of set 0 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=leningradskiy
# Processing record 14 of set 0 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=chuy
# Processing record 15 of set 0 | keshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=keshan
# City not found!
# Processing record 16 of set 0 | corowa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=corowa
# Processing record 17 of set 0 | kitami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kitami
# Processing record 18 of set 0 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=albany
# Processing record 19 of set 0 | revda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=revda
# Processing record 20 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=rikitea
# Processing record 21 of set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mataura
# Processing record 22 of set 0 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=nizhneyansk
# City not found!
# Processing record 23 of set 0 | jiuquan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=jiuquan
# Processing record 24 of set 0 | nilanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=nilanga
# Processing record 25 of set 0 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=vaitupu
# City not found!
# Processing record 26 of set 0 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mount gambier
# Processing record 27 of set 0 | mujiayingzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mujiayingzi
# Processing record 28 of set 0 | oster
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=oster
# Processing record 29 of set 0 | straumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=straumen
# Processing record 30 of set 0 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mount isa
# Processing record 31 of set 0 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mehamn
# Processing record 32 of set 0 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=saleaula
# City not found!
# Processing record 33 of set 0 | trairi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=trairi
# Processing record 34 of set 0 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=tiksi
# Processing record 35 of set 0 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=pevek
# Processing record 36 of set 0 | kayasula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kayasula
# Processing record 37 of set 0 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=maniitsoq
# Processing record 38 of set 0 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=avarua
# Processing record 39 of set 0 | cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=cairns
# Processing record 40 of set 0 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=saint-francois
# Processing record 41 of set 0 | sao joao dos patos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=sao joao dos patos
# Processing record 42 of set 0 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kapaa
# Processing record 43 of set 0 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=hermanus
# Processing record 44 of set 0 | ziro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ziro
# Processing record 45 of set 0 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=provideniya
# Processing record 46 of set 0 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=yellowknife
# Processing record 47 of set 0 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=rawson
# Processing record 48 of set 0 | nagato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=nagato
# Processing record 49 of set 0 | ribeira brava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ribeira brava
# Processing record 50 of set 0 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=jamestown
# Processing record 0 of set 1 | singleton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=singleton
# Processing record 1 of set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=cape town
# Processing record 2 of set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=castro
# Processing record 3 of set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mahebourg
# Processing record 4 of set 1 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=upernavik
# Processing record 5 of set 1 | maltahohe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=maltahohe
# Processing record 6 of set 1 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=sorland
# Processing record 7 of set 1 | eldikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=eldikan
# City not found!
# Processing record 8 of set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=east london
# Processing record 9 of set 1 | zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=zhezkazgan
# Processing record 10 of set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=saskylakh
# Processing record 11 of set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=hithadhoo
# Processing record 12 of set 1 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mys shmidta
# City not found!
# Processing record 13 of set 1 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=lagoa
# Processing record 14 of set 1 | sakakah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=sakakah
# City not found!
# Processing record 15 of set 1 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=sao filipe
# Processing record 16 of set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=tuktoyaktuk
# Processing record 17 of set 1 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=karratha
# Processing record 18 of set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mar del plata
# Processing record 19 of set 1 | salta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=salta
# Processing record 20 of set 1 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=luderitz
# Processing record 21 of set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=puerto ayora
# Processing record 22 of set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=punta arenas
# Processing record 23 of set 1 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=saint-joseph
# Processing record 24 of set 1 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=chapais
# Processing record 25 of set 1 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=tsihombe
# City not found!
# Processing record 26 of set 1 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=cabo san lucas
# Processing record 27 of set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=butaritari
# Processing record 28 of set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=georgetown
# Processing record 29 of set 1 | alotau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=alotau
# City not found!
# Processing record 30 of set 1 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=petropavlovsk-kamchatskiy
# Processing record 31 of set 1 | mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mackay
# Processing record 32 of set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=khatanga
# Processing record 33 of set 1 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ilulissat
# Processing record 34 of set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=saint-philippe
# Processing record 35 of set 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kavieng
# Processing record 36 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=atuona
# Processing record 37 of set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=qaanaaq
# Processing record 38 of set 1 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=berdigestyakh
# Processing record 39 of set 1 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=hasaki
# Processing record 40 of set 1 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=sobolevo
# Processing record 41 of set 1 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ponta do sol
# Processing record 42 of set 1 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=amderma
# City not found!
# Processing record 43 of set 1 | bushenyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=bushenyi
# Processing record 44 of set 1 | awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=awjilah
# Processing record 45 of set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=vaini
# Processing record 46 of set 1 | saint simons
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=saint simons
# Processing record 47 of set 1 | vozhega
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=vozhega
# Processing record 48 of set 1 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=geraldton
# Processing record 49 of set 1 | umm ruwabah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=umm ruwabah
# City not found!
# Processing record 50 of set 1 | itaperuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=itaperuna
# Processing record 0 of set 2 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=faanui
# Processing record 1 of set 2 | barretos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=barretos
# Processing record 2 of set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=thompson
# Processing record 3 of set 2 | santa cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=santa cruz
# Processing record 4 of set 2 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kutum
# Processing record 5 of set 2 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=beloha
# Processing record 6 of set 2 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=bethel
# Processing record 7 of set 2 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=belushya guba
# City not found!
# Processing record 8 of set 2 | san jose de ocoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=san jose de ocoa
# Processing record 9 of set 2 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=muros
# Processing record 10 of set 2 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kodiak
# Processing record 11 of set 2 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=isangel
# Processing record 12 of set 2 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=cockburn town
# Processing record 13 of set 2 | tromso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=tromso
# Processing record 14 of set 2 | chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=chicama
# Processing record 15 of set 2 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=lata
# Processing record 16 of set 2 | scarborough
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=scarborough
# Processing record 17 of set 2 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=port elizabeth
# Processing record 18 of set 2 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=saldanha
# Processing record 19 of set 2 | miracema do tocantins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=miracema do tocantins
# Processing record 20 of set 2 | denpasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=denpasar
# Processing record 21 of set 2 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=severo-kurilsk
# Processing record 22 of set 2 | pontianak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=pontianak
# Processing record 23 of set 2 | gorno-altaysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=gorno-altaysk
# Processing record 24 of set 2 | ewo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ewo
# Processing record 25 of set 2 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=fort nelson
# Processing record 26 of set 2 | lerwick
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=lerwick
# Processing record 27 of set 2 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=arraial do cabo
# Processing record 28 of set 2 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=umzimvubu
# City not found!
# Processing record 29 of set 2 | chamrajnagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=chamrajnagar
# Processing record 30 of set 2 | cartagena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=cartagena
# Processing record 31 of set 2 | buerarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=buerarema
# Processing record 32 of set 2 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=shimoda
# Processing record 33 of set 2 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=lasa
# Processing record 34 of set 2 | sennoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=sennoy
# Processing record 35 of set 2 | abbeville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=abbeville
# Processing record 36 of set 2 | natal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=natal
# Processing record 37 of set 2 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=cherskiy
# Processing record 38 of set 2 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=carnarvon
# Processing record 39 of set 2 | marrakesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=marrakesh
# Processing record 40 of set 2 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=tuatapere
# Processing record 41 of set 2 | sant julia de loria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=sant julia de loria
# Processing record 42 of set 2 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=narsaq
# Processing record 43 of set 2 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=hambantota
# Processing record 44 of set 2 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=berlevag
# Processing record 45 of set 2 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=tual
# Processing record 46 of set 2 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=iqaluit
# Processing record 47 of set 2 | kresttsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kresttsy
# Processing record 48 of set 2 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=yumen
# Processing record 49 of set 2 | omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=omsukchan
# Processing record 50 of set 2 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mayo
# Processing record 0 of set 3 | tikhvin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=tikhvin
# Processing record 1 of set 3 | blagoyevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=blagoyevo
# Processing record 2 of set 3 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=alice springs
# Processing record 3 of set 3 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=clyde river
# Processing record 4 of set 3 | rauma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=rauma
# Processing record 5 of set 3 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=nikolskoye
# Processing record 6 of set 3 | plavinas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=plavinas
# Processing record 7 of set 3 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=tasiilaq
# Processing record 8 of set 3 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=bambous virieux
# Processing record 9 of set 3 | balkhash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=balkhash
# Processing record 10 of set 3 | chokwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=chokwe
# City not found!
# Processing record 11 of set 3 | nefteyugansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=nefteyugansk
# Processing record 12 of set 3 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=hofn
# Processing record 13 of set 3 | tsienyane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=tsienyane
# City not found!
# Processing record 14 of set 3 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=lorengau
# Processing record 15 of set 3 | mapiripan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mapiripan
# Processing record 16 of set 3 | marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=marzuq
# Processing record 17 of set 3 | nezhinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=nezhinka
# Processing record 18 of set 3 | bani walid
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=bani walid
# Processing record 19 of set 3 | bestobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=bestobe
# Processing record 20 of set 3 | litovko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=litovko
# Processing record 21 of set 3 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=saint anthony
# Processing record 22 of set 3 | griffin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=griffin
# Processing record 23 of set 3 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ixtapa
# Processing record 24 of set 3 | manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=manokwari
# Processing record 25 of set 3 | agirish
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=agirish
# Processing record 26 of set 3 | fort saint james
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=fort saint james
# Processing record 27 of set 3 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=palabuhanratu
# City not found!
# Processing record 28 of set 3 | neepawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=neepawa
# Processing record 29 of set 3 | acari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=acari
# Processing record 30 of set 3 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=lebu
# Processing record 31 of set 3 | sakata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=sakata
# Processing record 32 of set 3 | oranjestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=oranjestad
# Processing record 33 of set 3 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=meulaboh
# Processing record 34 of set 3 | miramar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=miramar
# Processing record 35 of set 3 | viligili
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=viligili
# City not found!
# Processing record 36 of set 3 | monetnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=monetnyy
# Processing record 37 of set 3 | gao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=gao
# Processing record 38 of set 3 | mantua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mantua
# Processing record 39 of set 3 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=coihaique
# Processing record 40 of set 3 | barra do garcas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=barra do garcas
# Processing record 41 of set 3 | vrangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=vrangel
# Processing record 42 of set 3 | grandview
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=grandview
# Processing record 43 of set 3 | jujuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=jujuy
# City not found!
# Processing record 44 of set 3 | valparaiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=valparaiso
# Processing record 45 of set 3 | dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=dukat
# Processing record 46 of set 3 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=souillac
# Processing record 47 of set 3 | vysokogornyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=vysokogornyy
# Processing record 48 of set 3 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=illoqqortoormiut
# City not found!
# Processing record 49 of set 3 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kavaratti
# Processing record 50 of set 3 | katima mulilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=katima mulilo
# Processing record 0 of set 4 | nador
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=nador
# Processing record 1 of set 4 | acarau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=acarau
# City not found!
# Processing record 2 of set 4 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=hobart
# Processing record 3 of set 4 | arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=arman
# Processing record 4 of set 4 | kadan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kadan
# Processing record 5 of set 4 | fuyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=fuyang
# Processing record 6 of set 4 | guiratinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=guiratinga
# Processing record 7 of set 4 | phan rang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=phan rang
# City not found!
# Processing record 8 of set 4 | kattivakkam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kattivakkam
# Processing record 9 of set 4 | mizan teferi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mizan teferi
# Processing record 10 of set 4 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=labuhan
# Processing record 11 of set 4 | mount pleasant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mount pleasant
# Processing record 12 of set 4 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ancud
# Processing record 13 of set 4 | niquelandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=niquelandia
# Processing record 14 of set 4 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=chokurdakh
# Processing record 15 of set 4 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=esperance
# Processing record 16 of set 4 | belaya gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=belaya gora
# Processing record 17 of set 4 | chimbote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=chimbote
# Processing record 18 of set 4 | auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=auki
# Processing record 19 of set 4 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=padang
# Processing record 20 of set 4 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=bandarbeyla
# Processing record 21 of set 4 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=yerbogachen
# Processing record 22 of set 4 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ahipara
# Processing record 23 of set 4 | nguiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=nguiu
# City not found!
# Processing record 24 of set 4 | puerto lopez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=puerto lopez
# City not found!
# Processing record 25 of set 4 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=barrow
# Processing record 26 of set 4 | cavalcante
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=cavalcante
# Processing record 27 of set 4 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=bathsheba
# Processing record 28 of set 4 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=vanimo
# Processing record 29 of set 4 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kruisfontein
# Processing record 30 of set 4 | taguatinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=taguatinga
# Processing record 31 of set 4 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=vardo
# Processing record 32 of set 4 | lookan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=lookan
# Processing record 33 of set 4 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=sentyabrskiy
# City not found!
# Processing record 34 of set 4 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=alofi
# Processing record 35 of set 4 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=pangnirtung
# Processing record 36 of set 4 | beruwala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=beruwala
# Processing record 37 of set 4 | koksijde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=koksijde
# Processing record 38 of set 4 | mazagao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mazagao
# Processing record 39 of set 4 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=korla
# City not found!
# Processing record 40 of set 4 | syracuse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=syracuse
# Processing record 41 of set 4 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kahului
# Processing record 42 of set 4 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=hay river
# Processing record 43 of set 4 | saryshagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=saryshagan
# City not found!
# Processing record 44 of set 4 | barcelona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=barcelona
# Processing record 45 of set 4 | saryg-sep
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=saryg-sep
# Processing record 46 of set 4 | chhatapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=chhatapur
# Processing record 47 of set 4 | boshnyakovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=boshnyakovo
# Processing record 48 of set 4 | at-bashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=at-bashi
# Processing record 49 of set 4 | saurimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=saurimo
# Processing record 50 of set 4 | bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=bowen
# Processing record 0 of set 5 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=nanortalik
# Processing record 1 of set 5 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=norman wells
# Processing record 2 of set 5 | ilinsko-podomskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ilinsko-podomskoye
# City not found!
# Processing record 3 of set 5 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=nome
# Processing record 4 of set 5 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=constitucion
# Processing record 5 of set 5 | waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=waipawa
# Processing record 6 of set 5 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=nantucket
# Processing record 7 of set 5 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=barentsburg
# City not found!
# Processing record 8 of set 5 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=cidreira
# Processing record 9 of set 5 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=umm lajj
# Processing record 10 of set 5 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=comodoro rivadavia
# Processing record 11 of set 5 | yanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=yanan
# City not found!
# Processing record 12 of set 5 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=fortuna
# Processing record 13 of set 5 | waling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=waling
# City not found!
# Processing record 14 of set 5 | byron bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=byron bay
# Processing record 15 of set 5 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=bluff
# Processing record 16 of set 5 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=yeppoon
# Processing record 17 of set 5 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=san cristobal
# Processing record 18 of set 5 | kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kaeo
# Processing record 19 of set 5 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=attawapiskat
# City not found!
# Processing record 20 of set 5 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ribeira grande
# Processing record 21 of set 5 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=oranjemund
# Processing record 22 of set 5 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=srednekolymsk
# Processing record 23 of set 5 | mangrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mangrol
# Processing record 24 of set 5 | gueugnon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=gueugnon
# Processing record 25 of set 5 | buariki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=buariki
# City not found!
# Processing record 26 of set 5 | ilebo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ilebo
# Processing record 27 of set 5 | aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=aswan
# Processing record 28 of set 5 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=nemuro
# Processing record 29 of set 5 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=rocha
# Processing record 30 of set 5 | bam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=bam
# Processing record 31 of set 5 | stornoway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=stornoway
# City not found!
# Processing record 32 of set 5 | mazatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mazatlan
# Processing record 33 of set 5 | mabaruma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mabaruma
# Processing record 34 of set 5 | winnemucca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=winnemucca
# Processing record 35 of set 5 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=coquimbo
# Processing record 36 of set 5 | abeche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=abeche
# Processing record 37 of set 5 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=college
# Processing record 38 of set 5 | nova olimpia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=nova olimpia
# Processing record 39 of set 5 | keti bandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=keti bandar
# Processing record 40 of set 5 | boende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=boende
# Processing record 41 of set 5 | lembeni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=lembeni
# Processing record 42 of set 5 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=leshukonskoye
# Processing record 43 of set 5 | leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=leh
# Processing record 44 of set 5 | hare bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=hare bay
# Processing record 45 of set 5 | dudinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=dudinka
# Processing record 46 of set 5 | hit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=hit
# Processing record 47 of set 5 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=katsuura
# Processing record 48 of set 5 | adre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=adre
# Processing record 49 of set 5 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=samusu
# City not found!
# Processing record 50 of set 5 | emba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=emba
# Processing record 0 of set 6 | axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=axim
# Processing record 1 of set 6 | teya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=teya
# Processing record 2 of set 6 | mareeba
# ...
# Processing record 43 of set 9 | ushibuka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ushibuka
# Processing record 44 of set 9 | tamale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=tamale
# Processing record 45 of set 9 | buritama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=buritama
# Processing record 46 of set 9 | mergui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mergui
# City not found!
# Processing record 47 of set 9 | birao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=birao
# Processing record 48 of set 9 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=richards bay
# Processing record 49 of set 9 | catamarca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=catamarca
# City not found!
# Processing record 50 of set 9 | kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kenai
# Processing record 0 of set 10 | acuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=acuna
# City not found!
# Processing record 1 of set 10 | ghanzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ghanzi
# Processing record 2 of set 10 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=paamiut
# Processing record 3 of set 10 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=grand river south east
# City not found!
# Processing record 4 of set 10 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=port macquarie
# Processing record 5 of set 10 | pedasi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=pedasi
# Processing record 6 of set 10 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=buala
# Processing record 7 of set 10 | jardim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=jardim
# Processing record 8 of set 10 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=bubaque
# Processing record 9 of set 10 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=thinadhoo
# Processing record 10 of set 10 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=sinnamary
# Processing record 11 of set 10 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=adrar
# Processing record 12 of set 10 | yomitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=yomitan
# City not found!
# Processing record 13 of set 10 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=olafsvik
# City not found!
# Processing record 14 of set 10 | calvinia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=calvinia
# Processing record 15 of set 10 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=havoysund
# Processing record 16 of set 10 | wexford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=wexford
# Processing record 17 of set 10 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=tautira
# Processing record 18 of set 10 | lagunas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=lagunas
# Processing record 19 of set 10 | mandurah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mandurah
# Processing record 20 of set 10 | yei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=yei
# City not found!
# Processing record 21 of set 10 | merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=merauke
# Processing record 22 of set 10 | shimonoseki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=shimonoseki
# Processing record 23 of set 10 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=port hardy
# Processing record 24 of set 10 | iquique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=iquique
# Processing record 25 of set 10 | wenling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=wenling
# Processing record 26 of set 10 | tanquian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=tanquian
# City not found!
# Processing record 27 of set 10 | horconcitos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=horconcitos
# Processing record 28 of set 10 | ardakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ardakan
# Processing record 29 of set 10 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=maragogi
# Processing record 30 of set 10 | tidore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=tidore
# City not found!
# Processing record 31 of set 10 | mutare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mutare
# Processing record 32 of set 10 | george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=george
# Processing record 33 of set 10 | cortes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=cortes
# Processing record 34 of set 10 | kralendijk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kralendijk
# Processing record 35 of set 10 | naftah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=naftah
# City not found!
# Processing record 36 of set 10 | saint-felix-de-valois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=saint-felix-de-valois
# Processing record 37 of set 10 | darhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=darhan
# Processing record 38 of set 10 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=marcona
# City not found!
# Processing record 39 of set 10 | ogaminana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ogaminana
# Processing record 40 of set 10 | skjervoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=skjervoy
# Processing record 41 of set 10 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=dunedin
# Processing record 42 of set 10 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kaitangata
# Processing record 43 of set 10 | mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mecca
# Processing record 44 of set 10 | russkaya polyana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=russkaya polyana
# Processing record 45 of set 10 | beidao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=beidao
# Processing record 46 of set 10 | limoux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=limoux
# Processing record 47 of set 10 | monrovia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=monrovia
# Processing record 48 of set 10 | cutlerville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=cutlerville
# Processing record 49 of set 10 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=broome
# Processing record 50 of set 10 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=anadyr
# Processing record 0 of set 11 | roma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=roma
# Processing record 1 of set 11 | mariinskiy posad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=mariinskiy posad
# Processing record 2 of set 11 | avallon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=avallon
# Processing record 3 of set 11 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=cap malheureux
# Processing record 4 of set 11 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=dingle
# Processing record 5 of set 11 | campbell river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=campbell river
# Processing record 6 of set 11 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=port-gentil
# Processing record 7 of set 11 | bayir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=bayir
# Processing record 8 of set 11 | victor harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=victor harbor
# Processing record 9 of set 11 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=makakilo city
# Processing record 10 of set 11 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=husavik
# Processing record 11 of set 11 | waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=waingapu
# Processing record 12 of set 11 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=sisimiut
# Processing record 13 of set 11 | gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=gornopravdinsk
# Processing record 14 of set 11 | saint-junien
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=saint-junien
# Processing record 15 of set 11 | pousat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=pousat
# City not found!
# Processing record 16 of set 11 | saint-leu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=saint-leu
# Processing record 17 of set 11 | cururupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=cururupu
# Processing record 18 of set 11 | launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=launceston
# Processing record 19 of set 11 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=hami
# Processing record 20 of set 11 | ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ulladulla
# Processing record 21 of set 11 | alappuzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=alappuzha
# City not found!
# Processing record 22 of set 11 | chara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=chara
# Processing record 23 of set 11 | djambala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=djambala
# Processing record 24 of set 11 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=port lincoln
# Processing record 25 of set 11 | la asuncion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=la asuncion
# Processing record 26 of set 11 | jiayuguan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=jiayuguan
# Processing record 27 of set 11 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=plettenberg bay
# Processing record 28 of set 11 | iracoubo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=iracoubo
# Processing record 29 of set 11 | sokoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=sokoni
# Processing record 30 of set 11 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=victoria
# Processing record 31 of set 11 | faribault
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=faribault
# Processing record 32 of set 11 | rio de janeiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=rio de janeiro
# Processing record 33 of set 11 | sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=sambava
# Processing record 34 of set 11 | kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=kamenka
# Processing record 35 of set 11 | banka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=banka
# Processing record 36 of set 11 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=flinders
# Processing record 37 of set 11 | sumbawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=sumbawa
# City not found!
# Processing record 38 of set 11 | ingham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=ingham
# Processing record 39 of set 11 | pocone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=pocone
# Processing record 40 of set 11 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=praia da vitoria
# Processing record 41 of set 11 | shamgarh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc40273bbbf4cb8e9aee7fe659e2f605&q=shamgarh
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create a data frame from cities, temp, humidity, cloudiness and wind speed
weather_dict = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          539
# Cloudiness    539
# Country       539
# Date          539
# Humidity      539
# Temp          539
# Lat           539
# Lng           539
# Wind Speed    539
# dtype: int64

# %%
weather_data.head()
# Out:
#           City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0      ushuaia          75      AR  1578434232        81  51.80 -54.81
# 1         hilo          90      US  1578434232        65  78.80  19.71
# 2    busselton          26      AU  1578434232        60  62.01 -33.64
# 3      sanghar           1      IN  1578434233        96  48.76  29.48
# 4  port alfred         100      ZA  1578434233        98  68.00 -33.59
#
#       Lng  Wind Speed
# 0  -68.31        9.17
# 1 -155.08       17.22
# 2  115.35        4.45
# 3   73.93        4.12
# 4   26.89        1.01

# %%
cities_list = zip(new_cities,cloudiness,country,date,humidity,temp,lat,lng)
# Set variable for output file
output_file = os.path.join('output_data', 'cities.csv')
#  Open the output file
with open(output_file, 'w') as datafile:
    weather_data.to_csv(output_file)

# %%
date =datetime.datetime.fromtimestamp(
        int(weather_data['Date'][0])
    ).strftime('%m/%d/%Y')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Latitude Vs Temperature Plot

weather_data.plot(kind='scatter', x='Lat', y='Temp', c='Blue')
plt.title('City Latitude Vs Max Temperature ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.grid()
plt.savefig('Images/LatitudeVsTemperature.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Latitude Vs Humidity

weather_data.plot(kind='scatter',x='Lat',y='Humidity', c='Blue')
plt.title('City Latitude Vs Max Humidity ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.savefig("Images/LatitudeVsHumidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Latitude Vs Cloudiness

weather_data.plot(kind='scatter',x='Lat',y='Cloudiness', c='Blue')
plt.title('City Latitude Vs Cloudiness ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.savefig("Images/LatitudeVsCloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Latitude Vs Wind Speed

weather_data.plot(kind='scatter',x='Lat',y='Wind Speed', c='Blue')
plt.title('City Latitude Vs Wind Speed ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.savefig("Images/LatitudeVsWindSpeed.png")
